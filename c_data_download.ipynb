// %%
use GSS2022-Copy1.dta, clear

// %%
tab race
// Out:
//            race of respondent |      Freq.     Percent        Cum.
// ------------------------------+-----------------------------------
//                         white |      2,514       72.01       72.01
//                         black |        565       16.18       88.20
//                         other |        412       11.80      100.00
// ------------------------------+-----------------------------------
//                         Total |      3,491      100.00

// %%
tab educ coneduc
// Out:
//       highest year of |     confidence in education
//      school completed | a great d  only some  hardly an |     Total
// ----------------------+---------------------------------+----------
//   no formal schooling |         1          2          0 |         3
//                     1 |         0          1          0 |         1
//                     2 |         0          1          2 |         3
//                     3 |         1          5          0 |         6
//                     4 |         1          4          1 |         6
//                     5 |         2          1          1 |         4
//                     6 |         5          9          3 |        17
//                     7 |         5          3          0 |         8
//                     8 |         8          9          4 |        21
//                     9 |        12         18          8 |        38
//                    10 |        12         24         19 |        55
// ...

// %%
des
// Out:
// Contains data from GSS2022-Copy1.dta
//  Observations:         3,544
//     Variables:         1,061                  22 Jan 2024 18:45
// -------------------------------------------------------------------------------
// Variable      Storage   Display    Value
//     name         type    format    label      Variable label
// -------------------------------------------------------------------------------
// year            int     %29.0g     COUNTMISS
//                                               gss year for this respondent
// id              int     %8.0g                 respondent id number
// wrkstat         byte    %74.0g     WRKSTAT    labor force status
// hrs1            byte    %29.0g     WKHRS      number of hours worked last week
// hrs2            byte    %29.0g     WKHRS      number of hours usually work a
//                                                 week
// evwork          byte    %29.0g     YESNO      ever work as long as one year
// ...
